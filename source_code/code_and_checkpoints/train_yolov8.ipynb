# %%
# !nvidia-smi
# Out:
# Thu Nov  9 17:44:48 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...    Off | 00000000:01:00.0  On |                  N/A |
# | N/A   52C    P5              16W /  80W |     58MiB /  6144MiB |     25%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/peter/Documents/git-repo/MediaEval2023/source_code/code_and_checkpoints

# %%
# %pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.8.18 torch-1.12.1+cu113 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# Setup complete ✅ (16 CPUs, 15.0 GB RAM, 143.6/915.3 GB disk)

# %%
# %cd {HOME}

# !yolo task=detect mode=train model="models/yolov8n.pt" data=config.yaml epochs=2 imgsz=320 plots=True
# Out:
# /home/peter/Documents/git-repo/MediaEval2023/source_code/code_and_checkpoints
# Ultralytics YOLOv8.0.208 🚀 Python-3.8.18 torch-1.12.1+cu113 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train3/weights/best.pt conf=0.25 source="/home/peter/Documents/git-repo/MediaEval2023/source_code/code_and_checkpoints/test_dataset/TEST_data_medico_2023/*.mp4" save=True save_txt=True save_conf=True imgsz=640 show=True format="*.mp4"
# Out:
# /home/peter/Documents/git-repo/MediaEval2023/source_code/code_and_checkpoints
# Ultralytics YOLOv8.0.208 🚀 Python-3.8.18 torch-1.12.1+cu113 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/5 (1/1500) /home/peter/Documents/git-repo/MediaEval2023/source_code/code_and_checkpoints/test_dataset/TEST_data_medico_2023/66.mp4: 480x640 71 sperms, 8.7ms
# video 1/5 (2/1500) /home/peter/Documents/git-repo/MediaEval2023/source_code/code_and_checkpoints/test_dataset/TEST_data_medico_2023/66.mp4: 480x640 74 sperms, 6.8ms
# video 1/5 (3/1500) /home/peter/Documents/git-repo/MediaEval2023/source_code/code_and_checkpoints/test_dataset/TEST_data_medico_2023/66.mp4: 480x640 75 sperms, 6.5ms
# video 1/5 (4/1500) /home/peter/Documents/git-repo/MediaEval2023/source_code/code_and_checkpoints/test_dataset/TEST_data_medico_2023/66.mp4: 480x640 75 sperms, 7.0ms
# ...
